# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.
# ---
# 1. Generate a new set of 2000 random latitudes and longitudes.
# 2. Get the nearest city.
# 3. Perform an API call with the OpenWeatherMap.
# 4. Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The maximum temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.
# 5. Add the data to a new DataFrame.
# 6. Save the new DataFrame as a CSV file.

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 758

# %%
# Import the requests library.
import requests

# Import the time library.
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### Retrieve the following information from the API call.
#     - The latitude and longitude
#     - The Max temperature
#     - The % humidity
#     - The % cloudiness
#     - The Wind speed
#     - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | marabba
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | touros
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | thinadhoo
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | watertown
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | lahaina
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | berlevag
# Processing Record 17 of Set 1 | sungaipenuh
# Processing Record 18 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | tabou
# Processing Record 23 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | tabuk
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | okato
# Processing Record 29 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 1 | laguna
# Processing Record 31 of Set 1 | ixtapa
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | mogadishu
# Processing Record 41 of Set 1 | altay
# Processing Record 42 of Set 1 | taseyevo
# Processing Record 43 of Set 1 | batagay-alyta
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | olafsvik
# Processing Record 46 of Set 1 | male
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | severo-kurilsk
# Processing Record 49 of Set 1 | saint george
# Processing Record 50 of Set 1 | requena
# Processing Record 1 of Set 2 | khingansk
# Processing Record 2 of Set 2 | saint-augustin
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | lambarene
# Processing Record 5 of Set 2 | benjamin hill
# Processing Record 6 of Set 2 | adrar
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | honningsvag
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | simpang
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | nador
# Processing Record 15 of Set 2 | mbanza-ngungu
# Processing Record 16 of Set 2 | faanui
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | tazovskiy
# Processing Record 21 of Set 2 | lata
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | lancaster
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | pevek
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | buloh kasap
# Processing Record 30 of Set 2 | mackay
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | bandarbeyla
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | ginir
# Processing Record 37 of Set 2 | tura
# Processing Record 38 of Set 2 | victor harbor
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | bayburt
# Processing Record 41 of Set 2 | benghazi
# Processing Record 42 of Set 2 | husavik
# Processing Record 43 of Set 2 | puerto escondido
# Processing Record 44 of Set 2 | bambanglipuro
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | saint-paul
# Processing Record 47 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 2 | esperance
# Processing Record 49 of Set 2 | kousseri
# Processing Record 50 of Set 2 | pervomayskoye
# Processing Record 1 of Set 3 | bud
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | ulladulla
# Processing Record 5 of Set 3 | palmer
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | vao
# Processing Record 9 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 3 | ostrovnoy
# Processing Record 11 of Set 3 | eyl
# Processing Record 12 of Set 3 | omama
# Processing Record 13 of Set 3 | okoneshnikovo
# Processing Record 14 of Set 3 | usak
# Processing Record 15 of Set 3 | khani
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | mount isa
# Processing Record 18 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 3 | minot
# Processing Record 20 of Set 3 | callaway
# Processing Record 21 of Set 3 | hereford
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | mao
# Processing Record 24 of Set 3 | puerto leguizamo
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | sangar
# Processing Record 28 of Set 3 | rocha
# Processing Record 29 of Set 3 | tevaitoa
# Processing Record 30 of Set 3 | mangan
# Processing Record 31 of Set 3 | logan
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 3 | kidal
# Processing Record 35 of Set 3 | alappuzha
# Processing Record 36 of Set 3 | muros
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | komsomolskiy
# Processing Record 40 of Set 3 | hambantota
# Processing Record 41 of Set 3 | hwange
# Processing Record 42 of Set 3 | oistins
# Processing Record 43 of Set 3 | manacapuru
# Processing Record 44 of Set 3 | punta arenas
# Processing Record 45 of Set 3 | australind
# Processing Record 46 of Set 3 | edd
# Processing Record 47 of Set 3 | gordeyevka
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | raudeberg
# Processing Record 50 of Set 3 | guerrero negro
# Processing Record 1 of Set 4 | dingle
# Processing Record 2 of Set 4 | kuminskiy
# Processing Record 3 of Set 4 | albany
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | sabang
# Processing Record 6 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 7 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 4 | rabo de peixe
# Processing Record 9 of Set 4 | tomatlan
# Processing Record 10 of Set 4 | port lincoln
# Processing Record 11 of Set 4 | iesolo
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | batasan
# Processing Record 14 of Set 4 | fort-shevchenko
# Processing Record 15 of Set 4 | suntar
# Processing Record 16 of Set 4 | dunda
# Processing Record 17 of Set 4 | nogliki
# Processing Record 18 of Set 4 | lasa
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | khatanga
# Processing Record 21 of Set 4 | ketchikan
# Processing Record 22 of Set 4 | ballina
# Processing Record 23 of Set 4 | kapaa
# Processing Record 24 of Set 4 | lompoc
# Processing Record 25 of Set 4 | korampallam
# Processing Record 26 of Set 4 | swanzey
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | la seyne-sur-mer
# Processing Record 29 of Set 4 | magistralnyy
# Processing Record 30 of Set 4 | meiganga
# Processing Record 31 of Set 4 | udachnyy
# Processing Record 32 of Set 4 | mananara
# Processing Record 33 of Set 4 | old saybrook
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | kovernino
# Processing Record 36 of Set 4 | lethem
# Processing Record 37 of Set 4 | podor
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | sao filipe
# Processing Record 40 of Set 4 | spornoye
# Processing Record 41 of Set 4 | pak phanang
# Processing Record 42 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 4 | ciudad del maiz
# Processing Record 44 of Set 4 | segovia
# Processing Record 45 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 4 | bichura
# Processing Record 47 of Set 4 | clausthal-zellerfeld
# Processing Record 48 of Set 4 | viru
# Processing Record 49 of Set 4 | bethel
# Processing Record 50 of Set 4 | maltahohe
# Processing Record 1 of Set 5 | chazuta
# Processing Record 2 of Set 5 | pidhaytsi
# Processing Record 3 of Set 5 | arcoverde
# Processing Record 4 of Set 5 | iqaluit
# Processing Record 5 of Set 5 | xiaoyi
# Processing Record 6 of Set 5 | canandaigua
# Processing Record 7 of Set 5 | bantry
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | buchanan
# Processing Record 10 of Set 5 | cape canaveral
# Processing Record 11 of Set 5 | vestmannaeyjar
# Processing Record 12 of Set 5 | kieta
# Processing Record 13 of Set 5 | te anau
# Processing Record 14 of Set 5 | sensuntepeque
# Processing Record 15 of Set 5 | griffith
# Processing Record 16 of Set 5 | makushino
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | clyde river
# Processing Record 19 of Set 5 | oussouye
# Processing Record 20 of Set 5 | padang
# Processing Record 21 of Set 5 | bayonet point
# Processing Record 22 of Set 5 | alihe
# Processing Record 23 of Set 5 | kadnikov
# Processing Record 24 of Set 5 | shakawe
# Processing Record 25 of Set 5 | mangai
# Processing Record 26 of Set 5 | zhigalovo
# Processing Record 27 of Set 5 | sur
# Processing Record 28 of Set 5 | vardo
# Processing Record 29 of Set 5 | margate
# Processing Record 30 of Set 5 | viedma
# Processing Record 31 of Set 5 | chiredzi
# Processing Record 32 of Set 5 | coahuayana
# Processing Record 33 of Set 5 | dunedin
# Processing Record 34 of Set 5 | anderson
# Processing Record 35 of Set 5 | sobolevo
# Processing Record 36 of Set 5 | marystown
# Processing Record 37 of Set 5 | seoul
# Processing Record 38 of Set 5 | turtkul
# City not found. Skipping...
# Processing Record 39 of Set 5 | hofn
# Processing Record 40 of Set 5 | beringovskiy
# Processing Record 41 of Set 5 | atakpame
# Processing Record 42 of Set 5 | arrecife
# Processing Record 43 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 5 | yeppoon
# Processing Record 45 of Set 5 | tautira
# Processing Record 46 of Set 5 | marrakesh
# Processing Record 47 of Set 5 | arandis
# Processing Record 48 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 5 | millau
# Processing Record 50 of Set 5 | sorong
# Processing Record 1 of Set 6 | akdepe
# Processing Record 2 of Set 6 | mitsamiouli
# Processing Record 3 of Set 6 | egvekinot
# Processing Record 4 of Set 6 | nioki
# Processing Record 5 of Set 6 | chagoda
# Processing Record 6 of Set 6 | caravelas
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | cockburn town
# Processing Record 9 of Set 6 | awbari
# Processing Record 10 of Set 6 | butare
# Processing Record 11 of Set 6 | moerai
# Processing Record 12 of Set 6 | saskylakh
# Processing Record 13 of Set 6 | kokopo
# Processing Record 14 of Set 6 | jiazi
# Processing Record 15 of Set 6 | ancud
# Processing Record 16 of Set 6 | sidi ali
# Processing Record 17 of Set 6 | jind
# Processing Record 18 of Set 6 | lagoa
# Processing Record 19 of Set 6 | bamut
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | oriximina
# Processing Record 22 of Set 6 | seminole
# Processing Record 23 of Set 6 | kaduna
# Processing Record 24 of Set 6 | makakilo city
# Processing Record 25 of Set 6 | tocopilla
# Processing Record 26 of Set 6 | kearney
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | oloron-sainte-marie
# Processing Record 29 of Set 6 | kalpi
# Processing Record 30 of Set 6 | gbarnga
# Processing Record 31 of Set 6 | ribeira grande
# Processing Record 32 of Set 6 | port hardy
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | chegdomyn
# Processing Record 35 of Set 6 | mareeba
# Processing Record 36 of Set 6 | culpeper
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | avera
# Processing Record 40 of Set 6 | taywarah
# Processing Record 41 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 6 | rundu
# Processing Record 45 of Set 6 | zeya
# Processing Record 46 of Set 6 | campbell river
# Processing Record 47 of Set 6 | kokstad
# Processing Record 48 of Set 6 | san quintin
# Processing Record 49 of Set 6 | qorveh
# Processing Record 50 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 1 of Set 7 | hokitika
# Processing Record 2 of Set 7 | biak
# Processing Record 3 of Set 7 | poum
# Processing Record 4 of Set 7 | hobart
# Processing Record 5 of Set 7 | zyryanka
# Processing Record 6 of Set 7 | jiayuguan
# Processing Record 7 of Set 7 | siyabuswa
# Processing Record 8 of Set 7 | grindavik
# Processing Record 9 of Set 7 | liuhe
# Processing Record 10 of Set 7 | hualmay
# Processing Record 11 of Set 7 | tallahassee
# Processing Record 12 of Set 7 | sandane
# Processing Record 13 of Set 7 | kabo
# Processing Record 14 of Set 7 | sirfa
# City not found. Skipping...
# Processing Record 15 of Set 7 | zhanakorgan
# Processing Record 16 of Set 7 | busdi
# Processing Record 17 of Set 7 | torbay
# Processing Record 18 of Set 7 | aksarayskiy
# Processing Record 19 of Set 7 | eenhana
# Processing Record 20 of Set 7 | harbin
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | humaita
# Processing Record 23 of Set 7 | groningen
# Processing Record 24 of Set 7 | sarapul
# Processing Record 25 of Set 7 | san juan
# Processing Record 26 of Set 7 | new norfolk
# Processing Record 27 of Set 7 | uige
# Processing Record 28 of Set 7 | ternate
# Processing Record 29 of Set 7 | burica
# City not found. Skipping...
# Processing Record 30 of Set 7 | nhulunbuy
# Processing Record 31 of Set 7 | bushenyi
# Processing Record 32 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 7 | buraydah
# Processing Record 34 of Set 7 | hammerfest
# Processing Record 35 of Set 7 | cap malheureux
# Processing Record 36 of Set 7 | santana
# Processing Record 37 of Set 7 | solvychegodsk
# Processing Record 38 of Set 7 | cerro punta
# Processing Record 39 of Set 7 | beyneu
# Processing Record 40 of Set 7 | tarko-sale
# Processing Record 41 of Set 7 | port hedland
# Processing Record 42 of Set 7 | calhoun
# Processing Record 43 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 7 | san cristobal
# Processing Record 45 of Set 7 | tamworth
# Processing Record 46 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 7 | aktash
# Processing Record 48 of Set 7 | bukachacha
# Processing Record 49 of Set 7 | taksimo
# Processing Record 50 of Set 7 | port moresby
# Processing Record 1 of Set 8 | norman wells
# Processing Record 2 of Set 8 | asau
# Processing Record 3 of Set 8 | prince rupert
# Processing Record 4 of Set 8 | cerknica
# Processing Record 5 of Set 8 | hearst
# Processing Record 6 of Set 8 | luderitz
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 9 of Set 8 | luganville
# Processing Record 10 of Set 8 | tromso
# Processing Record 11 of Set 8 | thabazimbi
# Processing Record 12 of Set 8 | bereda
# Processing Record 13 of Set 8 | bolondron
# Processing Record 14 of Set 8 | arawa
# Processing Record 15 of Set 8 | bull savanna
# Processing Record 16 of Set 8 | thompson
# Processing Record 17 of Set 8 | constantine
# Processing Record 18 of Set 8 | ginda
# Processing Record 19 of Set 8 | pemangkat
# Processing Record 20 of Set 8 | schweinfurt
# Processing Record 21 of Set 8 | tarauaca
# Processing Record 22 of Set 8 | cantaura
# Processing Record 23 of Set 8 | chuy
# Processing Record 24 of Set 8 | non thai
# Processing Record 25 of Set 8 | boa vista
# Processing Record 26 of Set 8 | marsabit
# Processing Record 27 of Set 8 | cidreira
# Processing Record 28 of Set 8 | quang ngai
# Processing Record 29 of Set 8 | hauterive
# Processing Record 30 of Set 8 | henties bay
# Processing Record 31 of Set 8 | urumqi
# Processing Record 32 of Set 8 | huarmey
# Processing Record 33 of Set 8 | san carlos de bariloche
# Processing Record 34 of Set 8 | polignano a mare
# Processing Record 35 of Set 8 | aklavik
# Processing Record 36 of Set 8 | half moon bay
# Processing Record 37 of Set 8 | kaitangata
# Processing Record 38 of Set 8 | erzin
# Processing Record 39 of Set 8 | sao joao dos patos
# Processing Record 40 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 8 | itarema
# Processing Record 42 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 8 | necochea
# Processing Record 44 of Set 8 | suraabad
# Processing Record 45 of Set 8 | parana
# Processing Record 46 of Set 8 | muhos
# Processing Record 47 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 8 | huron
# Processing Record 49 of Set 8 | manicore
# Processing Record 50 of Set 8 | kahului
# Processing Record 1 of Set 9 | ust-kut
# Processing Record 2 of Set 9 | baykit
# Processing Record 3 of Set 9 | yanagawa
# Processing Record 4 of Set 9 | mayo
# Processing Record 5 of Set 9 | tanout
# Processing Record 6 of Set 9 | san andres
# Processing Record 7 of Set 9 | iberia
# Processing Record 8 of Set 9 | pointe michel
# Processing Record 9 of Set 9 | sept-iles
# Processing Record 10 of Set 9 | doka
# Processing Record 11 of Set 9 | juneau
# Processing Record 12 of Set 9 | amlame
# Processing Record 13 of Set 9 | kayerkan
# Processing Record 14 of Set 9 | gangtok
# Processing Record 15 of Set 9 | havre-saint-pierre
# Processing Record 16 of Set 9 | yar-sale
# Processing Record 17 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 9 | ulaanbaatar
# Processing Record 19 of Set 9 | gamba
# Processing Record 20 of Set 9 | pampa
# Processing Record 21 of Set 9 | hailar
# Processing Record 22 of Set 9 | belaya gora
# Processing Record 23 of Set 9 | pimentel
# Processing Record 24 of Set 9 | isla mujeres
# Processing Record 25 of Set 9 | vagur
# Processing Record 26 of Set 9 | flin flon
# Processing Record 27 of Set 9 | kirakira
# Processing Record 28 of Set 9 | manoel urbano
# Processing Record 29 of Set 9 | krasnoselkup
# Processing Record 30 of Set 9 | cobija
# Processing Record 31 of Set 9 | beaverlodge
# Processing Record 32 of Set 9 | atar
# Processing Record 33 of Set 9 | anadyr
# Processing Record 34 of Set 9 | tres lagoas
# Processing Record 35 of Set 9 | tyrma
# Processing Record 36 of Set 9 | milkovo
# Processing Record 37 of Set 9 | havelock
# Processing Record 38 of Set 9 | toro
# Processing Record 39 of Set 9 | camopi
# Processing Record 40 of Set 9 | muisne
# Processing Record 41 of Set 9 | longhua
# Processing Record 42 of Set 9 | lianzhou
# Processing Record 43 of Set 9 | acari
# Processing Record 44 of Set 9 | lorengau
# Processing Record 45 of Set 9 | pringsewu
# Processing Record 46 of Set 9 | saint albans
# Processing Record 47 of Set 9 | eureka
# Processing Record 48 of Set 9 | riyadh
# Processing Record 49 of Set 9 | udaipura
# Processing Record 50 of Set 9 | pangody
# Processing Record 1 of Set 10 | delcevo
# Processing Record 2 of Set 10 | flekkefjord
# Processing Record 3 of Set 10 | port hawkesbury
# Processing Record 4 of Set 10 | pangnirtung
# Processing Record 5 of Set 10 | sheridan
# Processing Record 6 of Set 10 | thyboron
# Processing Record 7 of Set 10 | seymchan
# Processing Record 8 of Set 10 | roald
# Processing Record 9 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 10 of Set 10 | wanning
# Processing Record 11 of Set 10 | tanete
# Processing Record 12 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 10 | sioux lookout
# Processing Record 14 of Set 10 | yumen
# Processing Record 15 of Set 10 | ati
# Processing Record 16 of Set 10 | bad kissingen
# Processing Record 17 of Set 10 | savannah bight
# Processing Record 18 of Set 10 | sao joao da barra
# Processing Record 19 of Set 10 | walvis bay
# Processing Record 20 of Set 10 | muravlenko
# Processing Record 21 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 10 | marfino
# Processing Record 23 of Set 10 | manuk mangkaw
# Processing Record 24 of Set 10 | kenora
# Processing Record 25 of Set 10 | comodoro rivadavia
# Processing Record 26 of Set 10 | betsiamites
# Processing Record 27 of Set 10 | senanga
# Processing Record 28 of Set 10 | sisimiut
# Processing Record 29 of Set 10 | saldanha
# Processing Record 30 of Set 10 | broken hill
# Processing Record 31 of Set 10 | epe
# Processing Record 32 of Set 10 | joniskis
# Processing Record 33 of Set 10 | boone
# Processing Record 34 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 10 | kavaratti
# Processing Record 36 of Set 10 | kikwit
# Processing Record 37 of Set 10 | gazanjyk
# Processing Record 38 of Set 10 | ishigaki
# Processing Record 39 of Set 10 | carutapera
# Processing Record 40 of Set 10 | sechura
# Processing Record 41 of Set 10 | meadow lake
# Processing Record 42 of Set 10 | arica
# Processing Record 43 of Set 10 | kushiro
# Processing Record 44 of Set 10 | bagdarin
# Processing Record 45 of Set 10 | talnakh
# Processing Record 46 of Set 10 | vieste
# Processing Record 47 of Set 10 | kilindoni
# Processing Record 48 of Set 10 | ust-omchug
# Processing Record 49 of Set 10 | clearlake
# Processing Record 50 of Set 10 | novyy urengoy
# Processing Record 1 of Set 11 | guadalupe y calvo
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | kenai
# Processing Record 4 of Set 11 | jiwani
# Processing Record 5 of Set 11 | pindiga
# Processing Record 6 of Set 11 | isangel
# Processing Record 7 of Set 11 | verkh-chebula
# Processing Record 8 of Set 11 | linguere
# Processing Record 9 of Set 11 | tevriz
# Processing Record 10 of Set 11 | pacific grove
# Processing Record 11 of Set 11 | faya
# Processing Record 12 of Set 11 | wynyard
# Processing Record 13 of Set 11 | hamilton
# Processing Record 14 of Set 11 | mandal
# Processing Record 15 of Set 11 | jumla
# Processing Record 16 of Set 11 | port macquarie
# Processing Record 17 of Set 11 | svobodnyy
# Processing Record 18 of Set 11 | noumea
# Processing Record 19 of Set 11 | zhigansk
# Processing Record 20 of Set 11 | trairi
# Processing Record 21 of Set 11 | estevan
# Processing Record 22 of Set 11 | santiago
# Processing Record 23 of Set 11 | barra patuca
# Processing Record 24 of Set 11 | severnoye
# Processing Record 25 of Set 11 | duz
# City not found. Skipping...
# Processing Record 26 of Set 11 | tateyama
# Processing Record 27 of Set 11 | la ronge
# Processing Record 28 of Set 11 | campo verde
# Processing Record 29 of Set 11 | dhidhdhoo
# Processing Record 30 of Set 11 | fairbanks
# Processing Record 31 of Set 11 | pisco
# Processing Record 32 of Set 11 | champerico
# Processing Record 33 of Set 11 | zajecar
# Processing Record 34 of Set 11 | srednekolymsk
# Processing Record 35 of Set 11 | ayagoz
# Processing Record 36 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 11 | bourail
# Processing Record 38 of Set 11 | kysyl-syr
# Processing Record 39 of Set 11 | najran
# Processing Record 40 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 11 | grand baie
# Processing Record 42 of Set 11 | bafq
# Processing Record 43 of Set 11 | kumano
# Processing Record 44 of Set 11 | turkistan
# Processing Record 45 of Set 11 | tessalit
# Processing Record 46 of Set 11 | bam
# Processing Record 47 of Set 11 | emerald
# Processing Record 48 of Set 11 | alta floresta
# Processing Record 49 of Set 11 | uxbridge
# Processing Record 50 of Set 11 | kamaishi
# Processing Record 1 of Set 12 | takoradi
# Processing Record 2 of Set 12 | vanavara
# Processing Record 3 of Set 12 | neuquen
# Processing Record 4 of Set 12 | sena madureira
# Processing Record 5 of Set 12 | constitucion
# Processing Record 6 of Set 12 | qui nhon
# Processing Record 7 of Set 12 | bolshoy uluy
# City not found. Skipping...
# Processing Record 8 of Set 12 | kodinsk
# Processing Record 9 of Set 12 | gushikawa
# Processing Record 10 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 12 | salto del guaira
# Processing Record 12 of Set 12 | tyret pervaya
# Processing Record 13 of Set 12 | kavieng
# Processing Record 14 of Set 12 | tahe
# Processing Record 15 of Set 12 | itambe
# Processing Record 16 of Set 12 | jega
# Processing Record 17 of Set 12 | ibipeba
# Processing Record 18 of Set 12 | sestri levante
# Processing Record 19 of Set 12 | libertador general san martin
# Processing Record 20 of Set 12 | hay river
# Processing Record 21 of Set 12 | inhambane
# Processing Record 22 of Set 12 | ambositra
# Processing Record 23 of Set 12 | haines junction
# Processing Record 24 of Set 12 | huicheng
# Processing Record 25 of Set 12 | cardston
# Processing Record 26 of Set 12 | yarmouth
# Processing Record 27 of Set 12 | tongren
# Processing Record 28 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 29 of Set 12 | grand-santi
# Processing Record 30 of Set 12 | cananea
# Processing Record 31 of Set 12 | coquimbo
# Processing Record 32 of Set 12 | nanortalik
# Processing Record 33 of Set 12 | bilibino
# Processing Record 34 of Set 12 | suoyarvi
# Processing Record 35 of Set 12 | aleksandrov gay
# Processing Record 36 of Set 12 | alugan
# Processing Record 37 of Set 12 | gold coast
# Processing Record 38 of Set 12 | sinazongwe
# Processing Record 39 of Set 12 | mabaruma
# Processing Record 40 of Set 12 | krupina
# Processing Record 41 of Set 12 | magdagachi
# Processing Record 42 of Set 12 | chumikan
# Processing Record 43 of Set 12 | kiruna
# Processing Record 44 of Set 12 | tombouctou
# Processing Record 45 of Set 12 | enshi
# Processing Record 46 of Set 12 | grants
# Processing Record 47 of Set 12 | aboisso
# Processing Record 48 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 12 | bemidji
# Processing Record 50 of Set 12 | mormugao
# Processing Record 1 of Set 13 | singapore
# Processing Record 2 of Set 13 | mestia
# Processing Record 3 of Set 13 | alofi
# Processing Record 4 of Set 13 | bobo dioulasso
# Processing Record 5 of Set 13 | westport
# Processing Record 6 of Set 13 | yenagoa
# Processing Record 7 of Set 13 | xudat
# Processing Record 8 of Set 13 | fairview
# Processing Record 9 of Set 13 | laiagam
# City not found. Skipping...
# Processing Record 10 of Set 13 | belica
# Processing Record 11 of Set 13 | banda aceh
# Processing Record 12 of Set 13 | eskilstuna
# Processing Record 13 of Set 13 | coihaique
# Processing Record 14 of Set 13 | xinzhou
# Processing Record 15 of Set 13 | paita
# Processing Record 16 of Set 13 | saint-georges
# Processing Record 17 of Set 13 | oytal
# Processing Record 18 of Set 13 | nachalovo
# Processing Record 19 of Set 13 | skibotn
# Processing Record 20 of Set 13 | sydney
# Processing Record 21 of Set 13 | hartselle
# Processing Record 22 of Set 13 | bilma
# Processing Record 23 of Set 13 | sao felix do xingu
# Processing Record 24 of Set 13 | san pedro
# Processing Record 25 of Set 13 | saint-joseph
# Processing Record 26 of Set 13 | chardara
# Processing Record 27 of Set 13 | nago
# Processing Record 28 of Set 13 | chunhuhub
# Processing Record 29 of Set 13 | ugoofaaru
# Processing Record 30 of Set 13 | yei
# Processing Record 31 of Set 13 | casino
# Processing Record 32 of Set 13 | sinnamary
# Processing Record 33 of Set 13 | bitung
# Processing Record 34 of Set 13 | kruisfontein
# Processing Record 35 of Set 13 | bathsheba
# Processing Record 36 of Set 13 | prado
# Processing Record 37 of Set 13 | gazli
# Processing Record 38 of Set 13 | svetlogorsk
# Processing Record 39 of Set 13 | hami
# Processing Record 40 of Set 13 | russell
# Processing Record 41 of Set 13 | lamar
# Processing Record 42 of Set 13 | nieuw amsterdam
# Processing Record 43 of Set 13 | guaymas
# Processing Record 44 of Set 13 | leshukonskoye
# Processing Record 45 of Set 13 | bom jesus
# Processing Record 46 of Set 13 | turayf
# Processing Record 47 of Set 13 | kempsey
# Processing Record 48 of Set 13 | mkuranga
# Processing Record 49 of Set 13 | mitu
# Processing Record 50 of Set 13 | balezino
# Processing Record 1 of Set 14 | allahabad
# Processing Record 2 of Set 14 | ambilobe
# Processing Record 3 of Set 14 | shimoda
# Processing Record 4 of Set 14 | tiarei
# Processing Record 5 of Set 14 | strezhevoy
# Processing Record 6 of Set 14 | zarya
# Processing Record 7 of Set 14 | victoria point
# Processing Record 8 of Set 14 | scarborough
# Processing Record 9 of Set 14 | shubarkuduk
# Processing Record 10 of Set 14 | grong
# Processing Record 11 of Set 14 | constanta
# Processing Record 12 of Set 14 | dobrinka
# Processing Record 13 of Set 14 | elizabeth city
# Processing Record 14 of Set 14 | santiago del estero
# Processing Record 15 of Set 14 | talara
# Processing Record 16 of Set 14 | ndele
# Processing Record 17 of Set 14 | rodrigues alves
# Processing Record 18 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 14 | graaff-reinet
# Processing Record 20 of Set 14 | usinsk
# Processing Record 21 of Set 14 | bowen
# Processing Record 22 of Set 14 | lenoir
# Processing Record 23 of Set 14 | ayan
# Processing Record 24 of Set 14 | samana
# Processing Record 25 of Set 14 | chandil
# Processing Record 26 of Set 14 | cartagena
# Processing Record 27 of Set 14 | riberalta
# Processing Record 28 of Set 14 | tibacuy
# Processing Record 29 of Set 14 | labuhan
# Processing Record 30 of Set 14 | balabac
# Processing Record 31 of Set 14 | gainesville
# Processing Record 32 of Set 14 | marzuq
# Processing Record 33 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 34 of Set 14 | parras
# City not found. Skipping...
# Processing Record 35 of Set 14 | casma
# Processing Record 36 of Set 14 | uthal
# Processing Record 37 of Set 14 | bogotol
# Processing Record 38 of Set 14 | bell ville
# Processing Record 39 of Set 14 | levelland
# Processing Record 40 of Set 14 | dire dawa
# Processing Record 41 of Set 14 | aksu
# Processing Record 42 of Set 14 | iracoubo
# Processing Record 43 of Set 14 | tall kayf
# Processing Record 44 of Set 14 | baoning
# Processing Record 45 of Set 14 | amapa
# Processing Record 46 of Set 14 | praia
# Processing Record 47 of Set 14 | semey
# Processing Record 48 of Set 14 | mingaora
# Processing Record 49 of Set 14 | gardelegen
# Processing Record 50 of Set 14 | wagrowiec
# Processing Record 1 of Set 15 | nalut
# Processing Record 2 of Set 15 | changli
# Processing Record 3 of Set 15 | itoman
# Processing Record 4 of Set 15 | baruun-urt
# Processing Record 5 of Set 15 | camacha
# Processing Record 6 of Set 15 | kuryk
# Processing Record 7 of Set 15 | tubinskiy
# Processing Record 8 of Set 15 | kozhevnikovo
# Processing Record 9 of Set 15 | bocas del toro
# Processing Record 10 of Set 15 | harper
# Processing Record 11 of Set 15 | kollumerland
# City not found. Skipping...
# Processing Record 12 of Set 15 | chesma
# Processing Record 13 of Set 15 | nisia floresta
# Processing Record 14 of Set 15 | nome
# Processing Record 15 of Set 15 | freetown
# Processing Record 16 of Set 15 | otavi
# Processing Record 17 of Set 15 | qaqortoq
# Processing Record 18 of Set 15 | camabatela
# Processing Record 19 of Set 15 | tommot
# Processing Record 20 of Set 15 | donskoye
# Processing Record 21 of Set 15 | obluche
# City not found. Skipping...
# Processing Record 22 of Set 15 | coremas
# Processing Record 23 of Set 15 | taian
# Processing Record 24 of Set 15 | trat
# Processing Record 25 of Set 15 | jabinyanah
# Processing Record 26 of Set 15 | tahta
# Processing Record 27 of Set 15 | tezu
# Processing Record 28 of Set 15 | chicama
# Processing Record 29 of Set 15 | namatanai
# Processing Record 30 of Set 15 | dunkwa
# Processing Record 31 of Set 15 | maceio
# Processing Record 32 of Set 15 | tomas oppus
# Processing Record 33 of Set 15 | vygonichi
# Processing Record 34 of Set 15 | dudinka
# Processing Record 35 of Set 15 | todiresti
# Processing Record 36 of Set 15 | karratha
# Processing Record 37 of Set 15 | along
# Processing Record 38 of Set 15 | ouesso
# Processing Record 39 of Set 15 | namibe
# Processing Record 40 of Set 15 | orsha
# Processing Record 41 of Set 15 | funadhoo
# Processing Record 42 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 15 | gambela
# Processing Record 44 of Set 15 | millinocket
# Processing Record 45 of Set 15 | mahajanga
# Processing Record 46 of Set 15 | hosangadi
# Processing Record 47 of Set 15 | bastia
# Processing Record 48 of Set 15 | rio bananal
# Processing Record 49 of Set 15 | arlit
# Processing Record 50 of Set 15 | iranshahr
# Processing Record 1 of Set 16 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 16 | kerema
# Processing Record 3 of Set 16 | galle
# Processing Record 4 of Set 16 | quatre cocos
# Processing Record 5 of Set 16 | abha
# Processing Record 6 of Set 16 | simao
# Processing Record 7 of Set 16 | pekalongan
# Processing Record 8 of Set 16 | malacacheta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0      Marabba  12.3500   32.1833     78.04       broken clouds        69
# 1        Tiksi  71.6872  128.8694     45.82       broken clouds        76
# 2         Lebu -37.6167  -73.6500     52.45     overcast clouds        96
# 3       Touros  -5.1989  -35.4608     71.65     overcast clouds        93
# 4  Tuktoyaktuk  69.4541 -133.0374     59.00       broken clouds        82
# 5    Thinadhoo   0.5333   72.9333     78.91     overcast clouds        84
# 6   Bredasdorp -34.5322   20.0403     47.23     overcast clouds        74
# 7    Watertown  42.3709  -71.1828     78.33           clear sky        79
# 8      Ushuaia -54.8000  -68.3000     31.66                snow        93
# 9    Geraldton -28.7667  114.6000     66.61    scattered clouds        59
#
#    Cloudiness  Wind Speed Country
# 0          83       13.42      SD
# 1          80        7.58      RU
# 2         100       12.12      CL
# 3         100        9.28      BR
# 4          75        8.05      CA
# 5         100       17.58      MV
# 6         100        5.32      ZA
# 7           0        4.61      US
# 8          75       26.46      AR
# 9          40        6.91      AU

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Marabba      SD  12.3500   32.1833     78.04        69          83
# 1        Tiksi      RU  71.6872  128.8694     45.82        76          80
# 2         Lebu      CL -37.6167  -73.6500     52.45        96         100
# 3       Touros      BR  -5.1989  -35.4608     71.65        93         100
# 4  Tuktoyaktuk      CA  69.4541 -133.0374     59.00        82          75
# 5    Thinadhoo      MV   0.5333   72.9333     78.91        84         100
# 6   Bredasdorp      ZA -34.5322   20.0403     47.23        74         100
# 7    Watertown      US  42.3709  -71.1828     78.33        79           0
# 8      Ushuaia      AR -54.8000  -68.3000     31.66        93          75
# 9    Geraldton      AU -28.7667  114.6000     66.61        59          40
#
#    Wind Speed Current Description
# 0       13.42       broken clouds
# 1        7.58       broken clouds
# 2       12.12     overcast clouds
# 3        9.28     overcast clouds
# 4        8.05       broken clouds
# 5       17.58     overcast clouds
# 6        5.32     overcast clouds
# 7        4.61           clear sky
# 8       26.46                snow
# 9        6.91    scattered clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
